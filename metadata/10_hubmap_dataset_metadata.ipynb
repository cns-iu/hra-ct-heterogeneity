# %% [markdown]
# # A notebook to get metadata for 10 HuBMAP datasets

# %% [markdown]
# # Import libraries

# %%
import requests
import argparse
import json
import pandas as pd
from pprint import pprint

# %% [markdown]
# # Define functions

# %%
def call_entity_api(endpoint: str, hubmap_id: str):
    """A function that calls the Entity API with the specified ID

    Args:
                    endpoint (str): Endpoint to call
                    hubmap_id (str): A HuBMAP ID
Returns:
                    data (json): the returned response in JSON
    """

    # get data from Entity API endpoint
    endpoint = f"https://entity.api.hubmapconsortium.org/{endpoint}/{hubmap_id}"

    # Use `argparse` to build URL
    parser = argparse.ArgumentParser(
        description="Get metadata for provided HuBMAP ID")
    parser.add_argument("--url", type=str,
                        help="URL of the API", default=endpoint)
    args, unknown = parser.parse_known_args()
    api_url = args.url

    # send request
    response = requests.get(api_url).text

    # parse to JSON
    data = json.loads(response)

    return data

# %% [markdown]
# # Main

# %%
# HuBMAP IDs to search for
ids = [
    "HBM948.GXMD.986",
    "HBM975.WQQQ.853",
    "HBM456.GRCM.369",
    "HBM762.RPDR.282",
    "HBM578.BDBP.672",
    "HBM675.RVGB.258",
    "HBM929.VSJQ.633",
    "HBM265.FQWZ.384",
    "HBM444.DXLZ.643",
    "HBM468.SSXX.967"
]

# Dictionary to capture the result
result = {
    'dataset_id': ids,
    'description': [],
    'donor_id': [],
    'dataset_info': [],
    'dataset_type': [],
    'group_name': [],
    'title': [],
    'uuid': []
}

# loop through ids and fetch data for ancestor and entity
for i in ids:

    # via ancestors endpoint
    ancestor_response = call_entity_api("ancestors", i)
    for ancestor in ancestor_response:
        if ancestor['entity_type'] == "Donor":
            result["description"].append(ancestor['description'])
            result['donor_id'].append(ancestor['hubmap_id'])

    # via entity endpoint
    entity_response = call_entity_api("entities", i)
    result['dataset_info'].append(entity_response['dataset_info'])
    result['dataset_type'].append(entity_response['dataset_type'])
    result['group_name'].append(entity_response['group_name'])
    result['title'].append(entity_response['title'])
    result['uuid'].append(entity_response['uuid'])

pprint(result)
# Out:
# {'dataset_id': ['HBM948.GXMD.986',
#                 'HBM975.WQQQ.853',
#                 'HBM456.GRCM.369',
#                 'HBM762.RPDR.282',
#                 'HBM578.BDBP.672',
#                 'HBM675.RVGB.258',
#                 'HBM929.VSJQ.633',
#                 'HBM265.FQWZ.384',
#                 'HBM444.DXLZ.643',
#                 'HBM468.SSXX.967'],
#  'dataset_info': ['salmon_rnaseq_snareseq__d2f1ba23eddf1484f4a794444a6536ee_01160f557b3544a163184137530ededf_7e452891b83ca984a2f210312d90495d_4ea28b66fb08185a484df0fa0b9543dc_eea962dabda0cec78f8f909494e0e775_e8efba8d06360eeba199f195da80f01d__salmon-rnaseq-snareseq',
#                   'salmon_rnaseq_snareseq__59da4436e52d9cacc743c1a9bbdd566f_c820345b025ff959e531db797030a399_19274e67c639a003ffe17953fd6b55db_d68eb55a484036b3575043bdecd64a52__salmon-rnaseq-snareseq',
#                   'salmon_rnaseq_snareseq__1bb63db033b3f7206a4d8c4ac4db1564_d615cc96a8606bb6819bed2a8d7f24ac_21cfe966008f784c47d0638e80b55ee0_500af39b83bfa9eb27f78746734f3db9__salmon-rnaseq-snareseq',
#                   'salmon_rnaseq_10x_sn__a8652e9e3c545e61e1ffe9d54a8f1fd2__salmon-rnaseq',
#                   'salmon_rnaseq_10x_sn__8e5c8f0cc61aad4fcbc5cc119bdf4c96__salmon-rnaseq',
#                   'salmon_rnaseq_10x_sn__26b642ddbae00e7ff6570ddd57557e26__salmon-rnaseq',
#                   'salmon_rnaseq_10x_sn__3b1490026022f850e4d3c3fb5e2283c9__salmon-rnaseq',
#                   'salmon_rnaseq_10x_sn__0736735768692d6ca0cd96149b743be1__salmon-rnaseq',
#                   'salmon_rnaseq_snareseq__11c92e3b876f5f79cd46a93eb90e074b_3a4b776346bfc561712eaf915dda6200_a8b5f09ae183be8731349bbb72a55a4f_e9e74364d8d9eeaba7a7f094d33c0a66__salmon-rnaseq-snareseq',
#                   'salmon_rnaseq_10x_sn__68e6dfa4807ca615883f73a5067115cb__salmon-rnaseq'],
#  'dataset_type': ['RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]',
#                   'RNAseq [Salmon]'],
#  'description': ['37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension',
#                  '37 yr old black male with intracranial hemorrhage and '
#                  'hypertension'],
#  'donor_id': ['HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877',
#               'HBM943.SCQQ.877'],
#  'group_name': ['University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC',
#                 'University of California San Diego TMC'],
#  'title': ['RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male',
#            'RNAseq [Salmon] data from the lung (right) of a 37-year-old black '
#            'or african american male'],
#  'uuid': ['dd648e4648238b25a7d1062669ea89af',
#           '176edb4b0e16059522f6f087576fbeec',
#           'a39fed027b51d97f83cec90c63c44744',
#           'e81c9c9753998b2ca69e8bceadf2409d',
#           '237b8f24c23821690519af862cf25a9f',
#           '171bd6114652ce2a1ff0e4757b5eaef9',
#           '37ccf28cb5c06e8ba076f587ee4e50be',
#           'd0c1bd09443c301413f44f7108d20e08',
#           '2dac500177620d78ca174c2c1d36a6c8',
#           '0b590c9e3a62178da592e85572e2f1bf']}

# %% [markdown]
# # Export result

# %%
df = pd.DataFrame(result)

df.to_csv("output/dataset_metadata.csv", index=False)
